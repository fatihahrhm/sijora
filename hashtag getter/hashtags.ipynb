# %%
import tweepy
import pandas as pd
import re

consumer_key = "h5g9VvA0TxfSFnru8fzSAQif4"
consumer_secret = "iIovoGF3J35LwgJ7Ht6SBhvWiDYdN8xn9SuVRvE4Z5vsZZYXCt"
access_token = "1067941386-2IigAD1hKedjeNLS3DKsInbdnZ33rutJwlWYTYk"
access_token_secret = "tEiKbY4HbS58g72EOcCnuVk09Th29qOSt5gT1FQlow9IE"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

tweets = tweepy.Cursor(api.user_timeline,
            id='DKIJakarta',
            q=" -filter:@",
            include_rts=False,
            exclude_replies=True,
            tweet_mode='extended').items(200)

# %%
tags = set()
for tweet in tweets:
    tags.update(set(re.findall(r"#(\w+)", tweet.full_text)))
tags
# Out:
# {'10thRJF',
#  '60TahunBankDKI',
#  '942dv',
#  'AniesBaswedan',
#  'BOR',
#  'BPBDDKIJakarta',
#  'BST',
#  'BankDKI',
#  'BankDKIBisa',
#  'BantuanSosialTunai',
#  'BersamaKitaBisa',
#  'BlokPemanduJalan',
#  'COVID19',
#  'CityofMural',
#  'ClimateAction',
#  'Covid19',
#  'DKIJakarta',
#  'DP0rupiahSamawa',
#  'DPRDProvinsiDKIJakarta',
#  'DamkarDKI',
#  'DataWarga',
#  'DiRumahAja',
#  'DinasPerumahanJakarta',
#  'DrainaseVertikal',
#  'DukcapilInfo',
#  'DukcapilJakarta',
#  'HKB2021',
#  'HadapiBersama',
#  'Hardiknas2021',
#  'HariBerbagiNasional',
#  'HariBumi',
#  'HariBumiSedunia',
#  'HariBuruh',
#  'IdentitasPola',
#  'IdentitasWarna',
#  'IdulFitri',
#  'JAKI',
#  'JXB',
#  'JagaJakarta',
#  'JagaJarak',
#  'Jagajakarta',
#  'JakBook',
#  'JakLingko',
#  'JakOneMobile',
#  'JakartaCreativeCompetition',
#  'JakartaKotaKolaborasi',
#  'JakartaRamahBersepeda',
#  'JakartaSmartCity',
#  'JakartaSmartcity',
#  'JakartaTanggapCorona',
#  'Jaklapor',
#  'Jakpreneur',
#  'JakpreneurFest',
#  'JakpreneurFest2021',
#  'KAJ',
#  'KJMU',
#  'KJP',
#  'KJPPlus',
#  'KLJ',
#  'KPCPEN',
#  'KPDJ',
#  'KRINanggala402',
#  'KartuPekerja',
#  'KeluargaWarnaMenor',
#  'KenaikanIsaAlmasih',
#  'KiosJakpreneur',
#  'KotaKolaborasi',
#  'LKPJ2020',
#  'Lebaran',
#  'Lebaran2021',
#  'Lebarandirumah',
#  'LindungiDiriLindungiNegeri',
#  'MRTJakarta',
#  'MayDay',
#  'MenabungAirHujan',
#  'MencuciTanganPakaiSabun',
#  'ModaIntegrasiTransportasiJabodetabek',
#  'OperasiSiagaIbuKota',
#  'PPID',
#  'PPIDJakarta',
#  'PPKM',
#  'PSBBJakarta',
#  'PakaiMasker',
#  'PandemiBelumUsai',
#  'PemprovDKIJakarta',
#  'PilarJatiBikePark',
#  'PlusJakarta',
#  'Ramadan',
#  'Ramadan1442H',
#  'Ramadhan',
#  'RukyatHilal',
#  'SayangiIndonesia',
#  'SayangiKeluargaKita',
#  'SehatBarengJakarta',
#  'Sehatbarengjakarta',
#  'SiapTanggapGalang',
#  'SukseskanVaksinasi',
#  'SumurResapan',
#  'SumurSerapan',
#  'TactilePaving',
#  'TemanTamanJakarta',
#  'TidakMudik',
#  'TransformasiDigital',
#  'TundaMudik',
#  'UMKM',
#  'UbahJakarta',
#  'VaksinasiCovid19',
#  'VaksinasiLansia',
#  'VaksinasiTahap2',
#  'VirtualTraveling',
#  'acaravirtual',
#  'aksiiklim',
#  'aksiuntukiklim',
#  'bangunjakarta',
#  'bansos',
#  'bantusesama',
#  'bedoccupancyrate',
#  'belanjahemat',
#  'beras',
#  'binamargadki',
#  'bpsdmdki',
#  'bpsdmdkijakarta',
#  'budidayamaggot',
#  'bukber',
#  'buku',
#  'bumddki',
#  'bussekolahjakarta',
#  'cegahbanjir',
#  'cegahkebakaran',
#  'ceritakorona',
#  'communityactionplan',
#  'covid19',
#  'dagingberkualitas',
#  'dharmajaya',
#  'dijakartaaja',
#  'dinaslhdki',
#  'dinasppkukm',
#  'dinassda',
#  'dinkesdki',
#  'dirumahaja',
#  'disbuddki',
#  'disdikdki',
#  'dishubdkijakarta',
#  'disparekrafdki',
#  'dkijakarta',
#  'dkpkpjakarta',
#  'dppappdki',
#  'drainasevertikal',
#  'dukungdarirumah',
#  'dutaimamtarawih',
#  'earthday',
#  'energiramadanjakarta',
#  'energiramadanjkt',
#  'energiramadhan',
#  'energiramadhanjkt',
#  'enjoyjakarta',
#  'flyovercakung',
#  'foodstation',
#  'fotoproduk',
#  'galungan',
#  'gereja',
#  'gerejabethelindonesia',
#  'hadapibersama',
#  'hampersRamadhan',
#  'happyeaster',
#  'hardiknas',
#  'hariangkutannasional',
#  'haribuku',
#  'haribukunasional',
#  'haribukusedunia',
#  'hariburuh',
#  'harikartini',
#  'harikonsumennasional',
#  'haripalangmerahinternasional',
#  'haripalangmerahsedunia',
#  'hariperawat',
#  'harkin',
#  'harkonas',
#  'hujanadalahrahmat',
#  'hutlrtjke3',
#  'idulfitri',
#  'infoKJP',
#  'inikampung',
#  'internationalnursesday',
#  'internetuntuksemua',
#  'jagajakarta',
#  'jakartabookhive',
#  'jakartacreativehub',
#  'jakartatanggapcorona',
#  'jakartatourism',
#  'jaki',
#  'jakita',
#  'jaklingko',
#  'jakpangan',
#  'jakpantau',
#  'jakpreneur',
#  'jktppc',
#  'jppc',
#  'jumatberkah',
#  'jxboard',
#  'kampungakuarium',
#  'kampungluarbatang',
#  'kampungsusun',
#  'kartini',
#  'kartuprakerja',
#  'kelompokwanitatani',
#  'ketahananpangan',
#  'konservasi',
#  'konsumenberdaya',
#  'konsumencerdas',
#  'kotakolaborasi',
#  'kotakolanborasi',
#  'kuningan',
#  'kwtteratai',
#  'laranganmudik2021',
#  'lawanCovid19',
#  'lebarandijakarta',
#  'lebarandirumah',
#  'lebarandirumahaja',
#  'lindungidirilindunginegeri',
#  'lrtjakarta',
#  'lrtjkt',
#  'masjidamirhamzahTIM',
#  'masjidjakarta',
#  'masjidluarbatang',
#  'matajkt',
#  'mayday2021',
#  'menabung',
#  'mentalhealth',
#  'mentalhelthawareness',
#  'mural',
#  'naramuda',
#  'naramudajakarta',
#  'ngabuburit',
#  'ngawi',
#  'ngobrolincovid19',
#  'nuansasamawa',
#  'olahragapuasa',
#  'operasikeselamatanjaya',
#  'paketsembako',
#  'palangmerahindonesia',
#  'pandemibelumusai',
#  'panduanibadah',
#  'pangansehat',
#  'paskah',
#  'pelecehanseksual',
#  'pembelajarantatapmuka',
#  'pemkabcilacap',
#  'penataankawasanstasiun',
#  'pengendalibanjir',
#  'perempuanberdaya',
#  'persijaday',
#  'persijajuara',
#  'pialamenpora2021',
#  'pilahsampah',
#  'planetariumjkt',
#  'plusjakarta',
#  'podcastrabubelajar',
#  'ppkm',
#  'ppkmjakarta',
#  'produklokal',
#  'puasa',
#  'rabubelajar',
#  'ramadan',
#  'ramadan2021',
#  'ramadhan2021',
#  'ramadhanjazz',
#  'recovertogether',
#  'reformasibirokrasi',
#  'rekayasalalin',
#  'rumahsakit',
#  'sampahmasker',
#  'samtama',
#  'sehatbarengjakarta',
#  'sekolahkolaborasi',
#  'sekolahtatapmuka',
#  'sembako',
#  'semuasiapsemuaselamat',
#  'siapdarisekarang',
#  'siapsekolah',
#  'siapuntukselamat',
#  'sklas',
#  'solusirumahwarga',
#  'stasiungondangdia',
#  'stasiuntebet',
#  'sukseskanvaksinasi',
#  'sumurresapan',
#  'takjil',
#  'takjiljakarta',
#  'tamanhutandki',
#  'tamanjakarta',
#  'tamanmajubersama',
#  'tarawih',
#  'telagasenibudayaislam',
#  'temantamanjakarta',
#  'tidakmudik',
#  'transportasijakarta',
#  'ukmjakarta',
#  'vaksinasiCOVID19',
#  'wirausaha',
#  'wisatabudaya',
#  'wisatadijakarta',
#  'wisatareligi'}
